# %% [markdown]
# <a href="https://colab.research.google.com/github/pankaj18/tensorflow_for_ml_and_dl/blob/master/1_tf_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# fit equation $y=2x$

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
x=np.array([-1,0,1,2,3,4,5],dtype=float)
y=np.array([-3,-1,1,3,5,7,9],dtype=float)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(x,y)

# %%
model=tf.keras.Sequential()
model.add(keras.layers.Dense(units=1,input_shape=[1]))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_2 (Dense)              (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='sgd',loss='mean_squared_error')

# %%
h=model.fit(x,y,epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 2ms/step - loss: 3.3639
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 2.5069
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9137
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5022
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2157
# Epoch 6/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0152
# Epoch 7/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8739
# Epoch 8/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7735
# Epoch 9/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7012
# Epoch 10/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6483
# Epoch 11/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6088
# Epoch 12/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5786
# ...

# %%
model.predict([10])
# Out:
# array([[18.982948]], dtype=float32)

# %%
plt.plot(h.history['loss'])
